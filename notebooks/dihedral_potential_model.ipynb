# %%
import numpy as np
from pymatgen import Molecule
from pymatgen.io.qchem import QcTask, QcOutput
import math

# %% [markdown]
# # Get dihedral angle and energy from qchem files

# %%
import os 
import re

# %%
# this is not placed in utils yet because error checking hasn't been finalized
def get_energy_dihedral(directory):
    dihedral, energy = [], []
    for f in os.listdir(directory):
        if ".qcout" in f:
            if ".orig" not in f:
                output = QcOutput('{d}/{f}'.format(d=directory,f=f))
                qchem_in = output.data[-1]['input']
                try:
                    energy.append(output.final_energy)
                except IndexError:
                    energy.append('no energy') 
                constraints = qchem_in.params['opt']
                for l in constraints:
                    if 'tors' in l:
                        dihedral.append(l[len(l)-1])
    return dihedral, energy

# %%
dihedral, energy = get_energy_dihedral('./pt_cust_dft_full')

# %% [markdown]
# # Fit and plot dihedral potential

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from scipy.optimize import curve_fit

# %%
# Ryckaert_Bellemans dihedral potential function
def RB_potential(x, a, b, c, d, e, f):
    return (a*1.0 + b*np.cos(x*np.pi/180.0) 
            + c*(np.cos(x*np.pi/180.0)**2) 
            + d*(np.cos(x*np.pi/180.0)**3) 
            + e*(np.cos(x*np.pi/180.0)**4) 
            + f*(np.cos(x*np.pi/180.0)**5))

# %%
import utils

# %%
rel_eV_energy = utils.relative_energy(energy)

# %%
fit_params, fit_covar = curve_fit(RB_potential,dihedral,rel_eV_energy)

# %%
# create list of angles and corresponding energies
angles = np.linspace(-180, 180, 3600)
RB_energy = [RB_potential(angle, fit_params[0], fit_params[1], 
                          fit_params[2], fit_params[3], fit_params[4], 
                          fit_params[5]) for angle in angles]

# %%
RB_energy1= [RB_potential(angle, *fit_params) for angle in angles]

# %%
RB_energy == RB_energy1
# Out:
# True

# %%
RB_energy
# Out:
# [0.0052399079270927544,
#  0.0052397549212286698,
#  0.0052392959206761505,
#  0.0052385309765534058,
#  0.0052374601740542972,
#  0.0052360836324437717,
#  0.0052344015050512878,
#  0.0052324139792625669,
#  0.0052301212765092303,
#  0.0052275236522568358,
#  0.0052246213959909037,
#  0.005221414831201106,
#  0.0052179043153636872,
#  0.005214090239921954,
#  0.0052099730302648832,
#  0.0052055531457039003,
#  0.0052008310794481255,
#  0.0051958073585769383,
#  0.0051904825440117009,
#  0.0051848572304849516,
#  0.0051789320465080143,
#  0.0051727076543367544,
#  0.0051661847499354123,
#  0.005159364062938588,
#  0.005152246356611572,
#  0.0051448324278085223,
#  0.0051371231069292896,
#  0.0051291192578738652,
#  0.005120821777995126,
#  0.0051122315980502769,
#  0.0051033496821498029,
#  0.0050941770277048819,
#  0.0050847146653729474,
#  0.0050749636590015686,
#  0.0050649251055701165,
#  0.0050546001351302232,
#  0.0050439899107438957,
#  0.0050330956284200543,
#  0.0050219185170492283,
#  0.0050104598383365236,
#  0.0049987208867327071,
#  0.004986702989363447,
#  0.0049744075059571409,
#  0.0049618358287700894,
#  0.0049489893825110012,
#  0.0049358696242629962,
#  0.0049224780434038128,
#  0.0049088161615248177,
#  0.004894885532347521,
#  0.0048806877416388058,
#  0.0048662244071243929,
#  0.0048514971784002154,
#  0.0048365077368425291,
#  0.0048212577955156037,
#  0.0048057490990785863,
#  0.0047899834236896166,
#  0.004773962576909074,
#  0.0047576883976004321,
#  0.0047411627558300714,
#  0.0047243875527646501,
#  0.0047073647205670525,
#  0.0046900962222912344,
#  0.0046725840517740291,
#  0.004654830233526701,
#  0.0046368368226237062,
#  0.0046186059045904403,
#  0.00460013959528902,
#  0.0045814400408024066,
#  0.0045625094173169459,
#  0.0045433499310029912,
#  0.0045239638178944178,
#  0.0045043533437656184,
#  0.0044845208040081609,
#  0.004464468523504031,
#  0.0044441988564989932,
#  0.0044237141864732392,
#  0.0044030169260105756,
#  0.0043821095166665215,
#  0.0043609944288341184,
#  0.0043396741616084479,
#  0.0043181512426498318,
#  0.0042964282280447451,
#  0.0042745077021659004,
#  0.0042523922775301844,
#  0.0042300845946553469,
#  0.0042075873219150246,
#  0.0041849031553923277,
#  0.0041620348187313789,
#  0.0041389850629883337,
#  0.0041157566664796336,
#  0.0040923524346296912,
#  0.0040687751998165185,
#  0.0040450278212162249,
#  0.0040211131846456761,
#  0.0039970342024036529,
#  0.0039727938131110339,
#  0.0039483949815488171,
#  0.0039238406984952023,
#  0.0038991339805607185,
#  0.0038742778700224766,
#  0.0038492754346564047,
#  0.0038241297675684956,
#  0.0037988439870243395,
#  0.0037734212362772858,
#  0.0037478646833952927,
#  0.0037221775210863192,
#  0.0036963629665222458,
#  0.0036704242611615128,
#  0.0036443646705703169,
#  0.0036181874842424345,
#  0.0035918960154176999,
#  0.0035654936008992083,
#  0.0035389836008689933,
#  0.0035123693987024387,
#  0.0034856544007816409,
#  0.0034588420363067286,
#  0.0034319357571069497,
#  0.0034049390374494013,
#  0.0033778553738470496,
#  0.0033506882848654872,
#  0.0033234413109280358,
#  0.0032961180141201467,
#  0.0032687219779919448,
#  0.0032412568073599381,
#  0.0032137261281073148,
#  0.0031861335869832483,
#  0.0031584828514006269,
#  0.0031307776092328729,
#  0.0031030215686094183,
#  0.0030752184577100663,
#  0.003047372024558237,
#  0.0030194860368128289,
#  0.0029915642815590933,
#  0.002963610565098535,
#  0.0029356287127372338,
#  0.0029076225685735037,
#  0.0028795959952840821,
#  0.0028515528739095197,
#  0.0028234971036381149,
#  0.0027954326015893552,
#  0.0027673633025954861,
#  0.002739293158982861,
#  0.0027112261403514021,
#  0.0026831662333540044,
#  0.002655117441473777,
#  0.0026270837848013946,
#  0.0025990692998105625,
#  0.0025710780391329383,
#  0.0025431140713321138,
#  0.0025151814806762323,
#  0.0024872843669100676,
#  0.0024594268450259449,
#  0.0024316130450337623,
#  0.0024038471117301223,
#  0.0023761332044663873,
#  0.002348475496916161,
#  0.0023208781768414575,
#  0.0022933454458584062,
#  0.002265881519201751,
#  0.0022384906254886159,
#  0.0022111770064817387,
#  0.0021839449168510154,
#  0.0021567986239352417,
#  0.0021297424075025157,
#  0.0021027805595097201,
#  0.0020759173838615329,
#  0.0020491571961684931,
#  0.0020225043235044425,
#  0.0019959631041628935,
#  0.0019695378874131277,
#  0.0019432330332552093,
#  0.0019170529121744235,
#  0.0018910019048948602,
#  0.0018650844021326713,
#  0.0018393048043481436,
#  0.0018136675214976373,
#  0.0017881769727842948,
#  0.0017628375864087321,
#  0.0017376537993185831,
#  0.0017126300569576024,
#  0.0016877708130144057,
#  0.0016630805291701781,
#  0.0016385636748461295,
#  0.0016142247269502249,
#  0.0015900681696234755,
#  0.0015660984939855453,
#  0.0015423201978800264,
#  0.0015187377856189553,
#  0.0014953557677269483,
#  0.0014721786606850034,
#  0.0014492109866733965,
#  0.0014264572733146143,
#  0.0014039220534155434,
#  0.0013816098647090932,
#  0.0013595252495958482,
#  0.0013376727548847747,
#  0.0013160569315339909,
#  0.0012946823343906217,
#  0.0012735535219310498,
#  0.0012526750559997955,
#  0.0012320515015490172,
#  0.001211687426377085,
#  0.0011915874008668736,
#  0.0011717559977240761,
#  0.0011521977917148597,
#  0.0011329173594033536,
#  0.0011139192788889715,
#  0.0010952081295433889,
#  0.0010767884917471196,
#  0.0010586649466262071,
#  0.0010408420757883883,
#  0.0010233244610590919,
#  0.0010061166842174709,
#  0.00098922332673201602,
#  0.0009726489694959848,
#  0.00095639819256287386,
#  0.00094047557488160551,
#  0.00092488569403168398,
#  0.00090963312595797232,
#  0.00089472244470577191,
#  0.00088015822215561012,
#  0.00086594502775759865,
#  0.00085208742826665051,
#  0.00083858998747659902,
#  0.00082545726595491947,
#  0.00081269382077731695,
#  0.00080030420526211324,
#  0.00078829296870497681,
#  0.00077666465611316016,
#  0.00076542380794034992,
#  0.00075457495982119262,
#  0.00074412264230590622,
#  0.0007340713805950895,
#  0.00072442569427451234,
#  0.00071519009704995628,
#  0.00070636909648242457,
#  0.00069796719372317668,
#  0.00068998888324889145,
#  0.00068243865259738547,
#  0.0006753209821029533,
#  0.00066864034463224881,
#  0.00066240120532026336,
#  0.00065660802130637587,
#  0.00065126524147088001,
#  0.00064637730617143853,
#  0.00064194864698006397,
#  0.00063798368642002407,
#  0.0006344868377035095,
#  0.0006314625044689247,
#  0.00062891508051911944,
#  0.00062684894955950367,
#  0.00062526848493659175,
#  0.00062417804937698598,
#  0.00062358199472665977,
#  0.00062348466169031896,
#  0.0006238903795716933,
#  0.00062480346601379152,
#  0.00062622822673954808,
#  0.00062816895529316675,
#  0.00063062993278157264,
#  0.00063361542761671474,
#  0.00063712969525771268,
#  0.00064117697795407083,
#  0.00064576150448903639,
#  0.00065088748992343229,
#  0.00065655913534030594,
#  0.00066278062758950984,
#  0.00066955613903374716,
#  0.00067688982729385621,
#  0.00068478583499600575,
#  0.00069324828951857018,
#  0.00070228130273975202,
#  0.00071188897078607646,
#  0.00072207537378121125,
#  0.00073284457559550905,
#  0.00074420062359630522,
#  0.00075614754839839612,
#  0.00076868936361582964,
#  0.00078183006561395162,
#  0.00079557363326214752,
#  0.00080992402768732125,
#  0.000824885192028375,
#  0.00084046105119076932,
#  0.00085665551160253508,
#  0.00087347246097032802,
#  0.00089091576803707962,
#  0.00090898928233942378,
#  0.00092769683396674288,
#  0.00094704223332055639,
#  0.00096702927087492785,
#  0.00098766171693743252,
#  0.0010089433214113428,
#  0.0010308778135582866,
#  0.0010534689017619391,
#  0.0010767202732925919,
#  0.0011006355940725572,
#  0.0011252185084424269,
#  0.00115047263892831,
#  0.001176401586009916,
#  0.0012030089278897327,
#  0.0012302982202628421,
#  0.0012582729960878562,
#  0.0012869367653589726,
#  0.0013162930148787359,
#  0.001346345208031893,
#  0.0013770967845602943,
#  0.0014085511603386526,
#  0.0014407117271515195,
#  0.0014735818524713126,
#  0.0015071648792369485,
#  0.0015414641256341465,
#  0.0015764828848764713,
#  0.0016122244249873259,
#  0.0016486919885833032,
#  0.001685888792658559,
#  0.0017238180283703237,
#  0.0017624828608252614,
#  0.0018018864288673838,
#  0.0018420318448668293,
#  0.0018829221945099121,
#  0.0019245605365903781,
#  0.0019669499028013735,
#  0.0020100932975295896,
#  0.0020539936976495345,
#  0.0020986540523197207,
#  0.0021440772827796954,
#  0.0021902662821485998,
#  0.0022372239152247137,
#  0.0022849530182863036,
#  0.0023334563988939463,
#  0.0023827368356937923,
#  0.0024327970782224593,
#  0.0024836398467128428,
#  0.0025352678319015428,
#  0.0025876836948376036,
#  0.0026408900666921261,
#  0.0026948895485699171,
#  0.0027496847113219437,
#  0.002805278095359273,
#  0.0028616722104685792,
#  0.0029188695356287125,
#  0.0029768725188287948,
#  0.0030356835768879085,
#  0.0030953050952757296,
#  0.0031557394279351039,
#  0.0032169888971055405,
#  0.0032790557931484032,
#  0.0033419423743738094,
#  0.0034056508668682587,
#  0.0034701834643244356,
#  0.0035355423278720247,
#  0.0036017295859103004,
#  0.0036687473339419548,
#  0.0037365976344085616,
#  0.0038052825165275639,
#  0.0038748039761306351,
#  0.0039451639755036898,
#  0.0040163644432285543,
#  0.0040884072740256005,
#  0.0041612943285988212,
#  0.0042350274334815525,
#  0.0043096083808844467,
#  0.004385038928544643,
#  0.0044613207995766275,
#  0.0045384556823246849,
#  0.0046164452302170315,
#  0.004695291061621228,
#  0.0047749947597018174,
#  0.0048555578722787448,
#  0.0049369819116882483,
#  0.0050192683546447852,
#  0.0051024186421049665,
#  0.0051864341791328285,
#  0.0052713163347670143,
#  0.0053570664418896331,
#  0.0054436857970965834,
#  0.005531175660569535,
#  0.0056195372559501022,
#  0.0057087717702150285,
#  0.0057988803535534532,
#  0.005889864119245837,
#  0.005981724143544683,
#  0.006074461465556822,
#  0.0061680770871272465,
#  0.0062625719727254494,
#  0.0063579470493323872,
#  0.0064542032063302805,
#  0.0065513412953933517,
#  0.0066493621303807572,
#  0.0067482664872311766,
#  0.0068480551038590815,
#  0.0069487286800530394,
#  0.0070502878773756154,
#  0.0071527333190647621,
#  0.0072560655899379664,
#  0.007360285236296866,
#  0.0074653927658348291,
#  0.0075713886475457948,
#  0.0076782733116349663,
#  0.0077860471494314593,
#  0.0078947105133025837,
#  0.0080042637165704499,
#  0.0081147070334294923,
#  0.0082260406988669422,
#  0.008338264908584277,
#  0.0084513798189211255,
#  0.0085653855467804803,
#  0.0086802821695562069,
#  0.0087960697250623922,
#  0.0089127482114642765,
#  0.0090303175872113277,
#  0.0091487777709720833,
#  0.0092681286415709704,
#  0.0093883700379268249,
#  0.0095095017589935538,
#  0.0096315235637026118,
#  0.0097544351709072628,
#  0.0098782362593287029,
#  0.010002926467504643,
#  0.010128505393738881,
#  0.010254972596053647,
#  0.010382327592143459,
#  0.010510569859330876,
#  0.010639698834524192,
#  0.010769713914177449,
#  0.01090061445425175,
#  0.011032399770179091,
#  0.011165069136827502,
#  0.011298621788469085,
#  0.011433056918748692,
#  0.011568373680655959,
#  0.011704571186498031,
#  0.011841648507875308,
#  0.0119796046756583,
#  0.012118438679966852,
#  0.012258149470151468,
#  0.012398735954776141,
#  0.012540197001603505,
#  0.012682531437581902,
#  0.012825738048834273,
#  0.012969815580649142,
#  0.013114762737473534,
#  0.013260578182907896,
#  0.013407260539702944,
#  0.013554808389758444,
#  0.013703220274124128,
#  0.013852494693002423,
#  0.014002630105753089,
#  0.014153624930900367,
#  0.014305477546141237,
#  0.014458186288356503,
#  0.014611749453623212,
#  0.014766165297229442,
#  0.014921432033691047,
#  0.015077547836770039,
#  0.015234510839495554,
#  0.015392319134186086,
#  0.015550970772474288,
#  0.015710463765333617,
#  0.015870796083106653,
#  0.016031965655535763,
#  0.016193970371795645,
#  0.016356808080527842,
#  0.01652047658987698,
#  0.016684973667529517,
#  0.016850297040754074,
#  0.017016444396443869,
#  0.017183413381161083,
#  0.01735120160118327,
#  0.017519806622551634,
#  0.017689225971121471,
#  0.017859457132614397,
#  0.018030497552672692,
#  0.01820234463691536,
#  0.018374995750996485,
#  0.018548448220665519,
#  0.018722699331829233,
#  0.018897746330615924,
#  0.019073586423441511,
#  0.01925021677707742,
#  0.019427634518720746,
#  0.019605836736066268,
#  0.019784820477379967,
#  0.019964582751575512,
#  0.020145120528291271,
#  0.020326430737970923,
#  0.020508510271944381,
#  0.020691355982511934,
#  0.020874964683029639,
#  0.021059333147996826,
#  0.021244458113145549,
#  0.021430336275531803,
#  0.021616964293629404,
#  0.021804338787424323,
#  0.021992456338512528,
#  0.022181313490198754,
#  0.0223709067475974,
#  0.02256123257773561,
#  0.022752287409657884,
#  0.0229440676345328,
#  0.02313656960576169,
#  0.023329789639088733,
#  0.023523724012713989,
#  0.023718368967406828,
#  0.023913720706622673,
#  0.024109775396620813,
#  0.024306529166583758,
#  0.024503978108740099,
#  0.024702118278486829,
#  0.024900945694515748,
#  0.025100456338940116,
#  0.025300646157424236,
#  0.025501511059314117,
#  0.025703046917770526,
#  0.025905249569903484,
#  0.026108114816908851,
#  0.026311638424206526,
#  0.026515816121580674,
#  0.026720643603321312,
#  0.026926116528368668,
#  0.027132230520457986,
#  0.027338981168267263,
#  0.027546364025566338,
#  0.0277543746113675,
#  0.02796300841007842,
#  0.028172260871656408,
#  0.028382127411764605,
#  0.028592603411930047,
#  0.028803684219702995,
#  0.029015365148818775,
#  0.029227641479360709,
#  0.029440508457924883,
#  0.02965396129778702,
#  0.029867995179070635,
#  0.030082605248917069,
#  0.030297786621657045,
#  0.030513534378984606,
#  0.030729843570131473,
#  0.030946709212044409,
#  0.031164126289563488,
#  0.031382089755601944,
#  0.031600594531328352,
#  0.031819635506349808,
#  0.032039207538897017,
#  0.032259305456010912,
#  0.032479924053731048,
#  0.032701058097285469,
#  0.032922702321282415,
#  0.033144851429902998,
#  0.033367500097096534,
#  0.033590642966776357,
#  0.033814274653017909,
#  0.034038389740258149,
#  0.034262982783496682,
#  0.034488048308497887,
#  0.034713580811995624,
#  0.034939574761898268,
#  0.035166024597496265,
#  0.035392924729670663,
#  0.035620269541103165,
#  0.035848053386487944,
#  0.036076270592744708,
#  0.036304915459233242,
#  0.036533982257969652,
#  0.036763465233843932,
#  0.036993358604838593,
#  0.037223656562249657,
#  0.037454353270908111,
#  0.037685442869403271,
#  0.037916919470307578,
#  0.03814877716040263,
#  0.038381010000906525,
#  0.038613612027703054,
#  0.038846577251571458,
#  0.039079899658418675,
#  0.039313573209511489,
#  0.039547591841711527,
#  0.039781949467710388,
#  0.040016639976266907,
#  0.040251657232444955,
#  0.040486995077853492,
#  0.040722647330887131,
#  0.040958607786968027,
#  0.041194870218789648,
#  0.041431428376561191,
#  0.041668275988253373,
#  0.041905406759845693,
#  0.042142814375574503,
#  0.042380492498182785,
#  0.042618434769170918,
#  0.042856634809048055,
#  0.043095086217586141,
#  0.043333782574073165,
#  0.04357271743756929,
#  0.043811884347163127,
#  0.04405127682222941,
#  0.044290888362687957,
#  0.0445307124492633,
#  0.044770742543746016,
#  0.045010972089254635,
#  0.045251394510498741,
#  0.045492003214043591,
#  0.045732791588574788,
#  0.045973753005165194,
#  0.046214880817541742,
#  0.046456168362354278,
#  0.046697608959444657,
#  0.046939195912116871,
#  0.047180922507409108,
#  0.047422782016365093,
#  0.047664767694308004,
#  0.047906872781114475,
#  0.048149090501489397,
#  0.048391414065242666,
#  0.04863383666756519,
#  0.048876351489307406,
#  0.049118951697257739,
#  0.049361630444421885,
#  0.049604380870303867,
#  0.049847196101186521,
#  0.050090069250414135,
#  0.050332993418675143,
#  0.050575961694285652,
#  0.050818967153474205,
#  0.051062002860666686,
#  0.0513050618687729,
#  0.051548137219472538,
#  0.051791221943503322,
#  0.052034309060949011,
#  0.052277391581528006,
#  0.052520462504883729,
#  0.052763514820874019,
#  0.053006541509862705,
#  0.053249535543011178,
#  0.053492489882570188,
#  0.053735397482173611,
#  0.053978251287130921,
#  0.054221044234722134,
#  0.054463769254492152,
#  0.054706419268545893,
#  0.054948987191844594,
#  0.055191465932501717,
#  0.055433848392080161,
#  0.055676127465889548,
#  0.055918296043284361,
#  0.056160347007962026,
#  0.056402273238262052,
#  0.056644067607465744,
#  0.05688572298409527,
#  0.057127232232214588,
#  0.057368588211729903,
#  0.057609783778690554,
#  0.057850811785591094,
#  0.058091665081672392,
#  0.058332336513224572,
#  0.058572818923889117,
#  0.058813105154962249,
#  0.059053188045697688,
#  0.059293060433610587,
#  0.059532715154781431,
#  0.059772145044159848,
#  0.060011342935869454,
#  0.060250301663512154,
#  0.060489014060473238,
#  0.060727472960226715,
#  0.060965671196640134,
#  0.061203601604280747,
#  0.061441257018720809,
#  0.061678630276843692,
#  0.061915714217149934,
#  0.06215250168006322,
#  0.062388985508237009,
#  0.062625158546860862,
#  0.062861013643966915,
#  0.06309654365073647,
#  0.063331741421806753,
#  0.063566599815577829,
#  0.06380111169451895,
#  0.064035269925475785,
#  0.064269067379976938,
#  0.064502496934541007,
#  0.064735551470983199,
#  0.06496822387672202,
#  0.065200507045086342,
#  0.06543239387562165,
#  0.065663877274397084,
#  0.065894950154311266,
#  0.066125605435399276,
#  0.066355836045138797,
#  0.066585634918756062,
#  0.066814994999531918,
#  0.067043909239107705,
#  0.06727237059779094,
#  0.067500372044860577,
#  0.067727906558872536,
#  0.067954967127964422,
#  0.068181546750160582,
#  0.068407638433676574,
#  0.068633235197223377,
#  0.068858330070311335,
#  0.069082916093554242,
#  0.069306986318972238,
#  0.069530533810295406,
#  0.069753551643266007,
#  0.06997603290594126,
#  0.070197970698995318,
#  0.070419358136020793,
#  0.070640188343830054,
#  0.070860454462756281,
#  0.071080149646953653,
#  0.071299267064697511,
#  0.071517799898683801,
#  0.07173574134632825,
#  0.071953084620064861,
#  0.072169822947644346,
#  0.072385949572431219,
#  0.072601457753701401,
#  0.072816340766938423,
#  0.073030591904129541,
#  0.073244204474061367,
#  0.073457171802614268,
#  0.073669487233057274,
#  0.073881144126341114,
#  0.074092135861391697,
#  0.074302455835402348,
#  0.074512097464125557,
#  0.074721054182164195,
#  0.07492931944326188,
#  0.075136886720592655,
#  0.07534374950705007,
#  0.075549901315535517,
#  0.075755335679245903,
#  0.075960046151960114,
#  0.076164026308325708,
#  0.076367269744143637,
#  0.076569770076653082,
#  0.076771520944815097,
#  0.076972516009595496,
#  0.077172748954247056,
#  0.077372213484590543,
#  0.077570903329295213,
#  0.07776881224015833,
#  0.077965933992383787,
#  0.078162262384859904,
#  0.078357791240436125,
#  0.078552514406198953,
#  0.078746425753746963,
#  0.078939519179464943,
#  0.079131788604796749,
#  0.079323227976517363,
#  0.079513831267004342,
#  0.079703592474507451,
#  0.079892505623418042,
#  0.080080564764537038,
#  0.080267763975341841,
#  0.080454097360252594,
#  0.08063955905089662,
#  0.080824143206372503,
#  0.08100784401351295,
#  0.081190655687146021,
#  0.081372572470355994,
#  0.081553588634742463,
#  0.081733698480678657,
#  0.081912896337568666,
#  0.082091176564102988,
#  0.082268533548513545,
#  0.082444961708827105,
#  0.082620455493117612,
#  0.08279500937975727,
#  0.082968617877666379,
#  0.083141275526561989,
#  0.083312976897205321,
#  0.083483716591647855,
#  0.08365348924347607,
#  0.083822289518055107,
#  0.083990112112770868,
#  0.08415695175727099,
#  0.084322803213704556,
#  0.084487661276960058,
#  0.084651520774902678,
#  0.084814376568609448,
#  0.084976223552603689,
#  0.085137056655087612,
#  0.085296870838173833,
#  0.085455661098115296,
#  0.085613422465533884,
#  0.085770150005647389,
#  0.085925838818495318,
#  0.086080484039163158,
#  0.086234080838005087,
#  0.086386624420865116,
#  0.086538110029297302,
#  0.086688532940783602,
#  0.086837888468950894,
#  0.08698617196378633,
#  0.087133378811850848,
#  0.087279504436491698,
#  0.08742454429805277,
#  0.087568493894083943,
#  0.08771134875954853,
#  0.087853104467029153,
#  0.087993756626932262,
#  0.08813330088769071,
#  0.088271732935964992,
#  0.08840904849684271,
#  0.088545243334036586,
#  0.088680313250080564,
#  0.088814254086524283,
#  0.088947061724126461,
#  0.089078732083045564,
#  0.089209261123029834,
#  0.089338644843604945,
#  0.089466879284260212,
#  0.089593960524633184,
#  0.089719884684692205,
#  0.089844647924917573,
#  0.089968246446480868,
#  0.090090676491422217,
#  0.090211934342826511,
#  0.09033201632499703,
#  0.090450918803627892,
#  0.090568638185974479,
#  0.090685170921022101,
#  0.090800513499652916,
#  0.090914662454810807,
#  0.091027614361664941,
#  0.091139365837770936,
#  0.091249913543230587,
#  0.091359254180849531,
#  0.091467384496293144,
#  0.09157430127824083,
#  0.09168000135853771,
#  0.091784481612345481,
#  0.091887738958290388,
#  0.091989770358610001,
#  0.092090572819297875,
#  0.092190143390246088,
#  0.092288479165386281,
#  0.092385577282828452,
#  0.092481434924997954,
#  0.092576049318770504,
#  0.092669417735605386,
#  0.092761537491676607,
#  0.092852405948001995,
#  0.092942020510570544,
#  0.093030378630467647,
#  0.093117477803998483,
#  0.093203315572809239,
#  0.093287889524006573,
#  0.093371197290274835,
#  0.093453236549991506,
#  0.093534005027340467,
#  0.093613500492423507,
#  0.093691720761369376,
#  0.093768663696441379,
#  0.093844327206142331,
#  0.093918709245318019,
#  0.093991807815258357,
#  0.094063620963796404,
#  0.094134146785405701,
#  0.094203383421295014,
#  0.09427132905950153,
#  0.094337981934981677,
#  0.094403340329700047,
#  0.094467402572716075,
#  0.094530167040268759,
#  0.094591632155859251,
#  0.094651796390331402,
#  0.094710658261950131,
#  0.094768216336477751,
#  0.094824469227248173,
#  0.094879415595239103,
#  0.094933054149141882,
#  0.094985383645429522,
#  0.095036402888422286,
#  0.095086110730351475,
#  0.095134506071420905,
#  0.095181587859866232,
#  0.095227355092012217,
#  0.095271806812327844,
#  0.095314942113479323,
#  0.095356760136380822,
#  0.095397260070243184,
#  0.095436441152620469,
#  0.095474302669454308,
#  0.095510843955116165,
#  0.095546064392447255,
#  0.095579963412796565,
#  0.095612540496056608,
#  0.095643795170696821,
#  0.095673727013795187,
#  0.095702335651067283,
#  0.095729620756893397,
#  0.095755582054343438,
#  0.095780219315199575,
#  0.095803532359976851,
#  0.095825521057941426,
#  0.095846185327126812,
#  0.095865525134347832,
#  0.095883540495212402,
#  0.095900231474131181,
#  0.095915598184324977,
#  0.095929640787830006,
#  0.09594235949550084,
#  0.095953754567011412,
#  0.095963826310853623,
#  0.095972575084333794,
#  0.095980001293566972,
#  0.095986105393469079,
#  0.095990887887746748,
#  0.095994349328885009,
#  0.095996490318132954,
#  0.095997311505486918,
#  0.095996813589671659,
#  0.095994997318119377,
#  0.095991863486946313,
#  0.095987412940927497,
#  0.095981646573468971,
#  0.09597456532657804,
#  0.095966170190831229,
#  0.095956462205340126,
#  0.095945442457714983,
#  0.095933112084026148,
#  0.095919472268763309,
#  0.095904524244792497,
#  0.09588826929331111,
#  0.095870708743800478,
#  0.095851843973976406,
#  0.095831676409737609,
#  0.095810207525111699,
#  0.095787438842199354,
#  0.095763371931116045,
#  0.095738008409931741,
#  0.095711349944608254,
#  0.095683398248934778,
#  0.095654155084460818,
#  0.095623622260427366,
#  0.095591801633695586,
#  0.095558695108673583,
#  0.095524304637240903,
#  0.095488632218670946,
#  0.095451679899551181,
#  0.095413449773701128,
#  0.095373943982088483,
#  0.095333164712742891,
#  0.095291114200667437,
#  0.095247794727748511,
#  0.095203208622662905,
#  0.095157358260783434,
#  0.095110246064081833,
#  0.095061874501030014,
#  0.095012246086498983,
#  0.094961363381655645,
#  0.094909228993857633,
#  0.094855845576545833,
#  0.094801215829135116,
#  0.094745342496902724,
#  0.094688228370874622,
#  0.094629876287709941,
#  0.094570289129583068,
#  0.09450946982406383,
#  0.094447421343995835,
#  0.09438414670737208,
#  0.09431964897720943,
#  0.094253931261420232,
#  0.094186996712682325,
#  0.094118848528306959,
#  0.094049489950104453,
#  0.093978924264248323,
#  0.093907154801136761,
#  0.093834184935252557,
#  0.093760018085020908,
#  0.093684657712665029,
#  0.09360810732406015,
#  0.093530370468585144,
#  0.093451450738972403,
#  0.093371351771155603,
#  0.093290077244115574,
#  0.093207630879724404,
#  0.09312401644258704,
#  0.093039237739881583,
#  0.092953298621197125,
#  0.092866202978370033,
#  0.092777954745318164,
#  0.092688557897872878,
#  0.092598016453609752,
#  0.092506334471676818,
#  0.092413516052621214,
#  0.092319565338213797,
#  0.092224486511272033,
#  0.092128283795480825,
#  0.092030961455211668,
#  0.091932523795339741,
#  0.091832975161059288,
#  0.091732319937697274,
#  0.091630562550524833,
#  0.091527707464567246,
#  0.091423759184411979,
#  0.091318722254014981,
#  0.091212601256504974,
#  ...]

# %%
plt.figure()
plt.plot(dihedral, rel_eV_energy, 'o', angles, RB_energy, 'black')
plt.xlabel('Dihedral angle')
plt.ylabel('Relative eV')
plt.show()

# %%
fit_params

# %% [markdown]
# # Boltzmann distribution

# %%
# kbT in eV/KS
kb_eV_K = 8.6173324 * 10**-5

# %%
kbT700 = kb_eV_K * 700.0
kbT300 = kb_eV_K * 300.0

# %%
# normalization 
boltz_factor_700 = [np.exp(-energy / kbT700) for energy in RB_energy]
normalize_val = sum(boltz_factor_700)

# %%
prob_700 = [(np.exp(-energy / kbT700) / normalize_val) for energy in RB_energy]

# %%
plt.figure()
plt.plot(angles, prob_700)
plt.xlabel('Diheadral angle')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# # Map dihedral angles to random numbers between 0-1

# %%
cum_prob = [sum(prob_700[0:prob_i]) for prob_i in range(len(prob_700))]

# %%
plt.figure()
plt.plot(cum_prob, angles)
plt.xlabel('Cumulative probability')
plt.ylabel('Dihedral angle')
plt.show()

# %%
n_prob_angle = np.array(zip(cum_prob, angles))
n_prob_angle

# %%
random = np.random.uniform(0.0, 1.0, size=(24-1))
angle_map = n_prob_angle[:, 0].searchsorted(random)
angle_map = np.array([0, 34, 85])

# %%
dihedral_set = []
for i in angle_map:
    rand = np.random.uniform(0.0, 1.0)
    if rand < 0.5:
        dihedral_set.append(n_prob_angle[i - 1][1])
    else:
        dihedral_set.append(n_prob_angle[i][1])

# %%
n_prob_angle[0][1]

# %%
dihedral_set

# %% [markdown]
# # Build, relax, and sample neutral chain

# %%
from polymer_chain import Polymer

# %%
monomer_num = 24
monomer_len = 2.548
link_len = 1.480
link_angle = 15.0
sample_num = 100

# %%
pt = Polymer(monomer_num, monomer_len, link_len, link_angle, n_prob_angle, sample_num)

# %%
#pt_neutal.build_chain()
#pt_neutal.relax_neutral_chain()

# %%
#%time ave_ete, ave_corr = pt.sample_neutral_chains()

# %%
#plt.figure()
#plt.plot(range(0, monomer_num + 1, 1), ave_ete)
#plt.xlabel('number of monomers')
#plt.ylabel('average end_to_end distance')
#plt.show()

# %%
#%timeit pt_neutal.sample_neutral_chains()

# %%
#1 loop, best of 3: 667 ms per loop

# %%
#ave_ete

# %%
#plt.figure()
#plt.plot(range(0, monomer_num + 1, 1), ((ave_ete * ave_ete)*0.01))
#plt.xlabel('number of monomers')
#plt.ylabel('average end_to_end distance')
#plt.show()

# %%
#plt.figure()
#plt.plot(range(0, monomer_num, 1), ave_corr)
#plt.xlabel('number of monomers')
#plt.ylabel('correlation')
#plt.show()

# %%
#plt.figure()
#plt.plot(range(0, monomer_num, 1), np.log(ave_corr))
#plt.xlabel('number of monomers')
#plt.ylabel('correlation')
#plt.show()

# %% [markdown]
# # Plot and fit charged dihedral potential

# %%
def get_energy_charged_dihedral(directory):
    dihedral, energy = [], []
    for f in os.listdir(directory):
        #print f
        if ".qcout" in f:
            if '_-90.0' not in f and '_100.0' not in f and '_140' not in f:
                #print f
                output = QcOutput('{d}/{f}'.format(d=directory,f=f))
                qchem_in = output.data[-1]['input']
                try:
                    energy.append(output.final_energy)
                except IndexError:
                    energy.append('no energy') 
                constraints = qchem_in.params['opt']
                for l in constraints:
                    if 'tors' in l:
                        dihedral.append(l[len(l)-1])
    return dihedral, energy

# %%
c_dihedral, c_energy = get_energy_charged_dihedral('./charged_dft_b3lyp_out/')

# %%
cc_energy = []
cc_dihedral = []
for i in range(len(c_energy)):
    if isinstance(c_energy[i], float):
        cc_energy.append(c_energy[i])
        cc_dihedral.append(c_dihedral[i])

# %%
c_rel_eV_energy = utils.relative_energy(cc_energy)

# %%
c_fit_params, c_fit_covar = curve_fit(RB_potential,cc_dihedral,c_rel_eV_energy)

# %%
# create list of angles and corresponding energies
c_angles = np.linspace(-180, 180, 3600)
c_RB_energy = [RB_potential(c_angle, c_fit_params[0], c_fit_params[1], 
                          c_fit_params[2], c_fit_params[3], c_fit_params[4], 
                          c_fit_params[5]) for c_angle in c_angles]

# %%
plt.figure()
plt.plot(cc_dihedral, c_rel_eV_energy, 'o', c_angles, c_RB_energy, 'black')
plt.xlabel('Dihedral angle')
plt.ylabel('Relative eV')
plt.show()

# %% [markdown]
# # Boltzmann distribution

# %%
# normalization 
c_boltz_factor_700 = [np.exp(-energy / kbT700) for energy in c_RB_energy]
c_normalize_val = sum(c_boltz_factor_700)

# %%
#c_boltz_factor_700

# %%
prob_700 = [(np.exp(-energy / kbT700) / c_normalize_val) for energy in c_RB_energy]

# %%
plt.figure()
plt.plot(c_angles, prob_700)
plt.xlabel('Diheadral angle')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# # Cumulative Probability

# %%
c_cum_prob = [sum(prob_700[0:prob_i]) for prob_i in range(len(prob_700))]

# %%
plt.figure()
plt.plot(c_cum_prob, c_angles)
plt.xlabel('Cumulative probability')
plt.ylabel('Dihedral angle')
plt.show()

# %%
c_prob_angle = np.array(zip(c_cum_prob, c_angles))

# %%
pt = Polymer(monomer_num, monomer_len, link_len, link_angle, n_prob_angle, sample_num, c_prob_angle)

# %%
pt.build_chain() 
n_chain, n_ete, c_chain, c_ete = pt.relax_charged_chain(1, values=True)

# %%
# [-165.09301860372074]
10

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(n_chain[:,0], n_chain[:,1], n_chain[:,2])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(c_chain[:,0], c_chain[:,1], c_chain[:,2])

# %%
c_ete, c_corr = pt.sample_charged_chains(1)

# %%
c_ete

# %%
c_corr

# %%
pt.n_random_angle()

# %%
# The slowest run took 5.79 times longer than the fastest. This could mean that an intermediate result is being cached.
#10000 loops, best of 3: 24.7 µs per loop

# %%
#   try:
                    #dihedral_set.append(self.n_prob_angle[prob_i][1])
                #except IndexError:

# %%
n_prob_angle[3600][1]

# %%
n_prob_angle[3599][1]
